# %% [markdown]
# # 資料訓練模組
#
# ## 前置套件安裝
# 在Python3.6, pip3.6 的環境下安裝所需套件

# %%
# !pip3.6 install pandas
# !pip3.6 install numpy
# !pip3.6 install scipy
# !pip3.6 install sklearn
# Out:
# Requirement already satisfied: pandas in /Library/Frameworks/Python.framework/Versions/3.6/lib/python3.6/site-packages
# Requirement already satisfied: numpy>=1.7.0 in /Library/Frameworks/Python.framework/Versions/3.6/lib/python3.6/site-packages (from pandas)
# Requirement already satisfied: pytz>=2011k in /Library/Frameworks/Python.framework/Versions/3.6/lib/python3.6/site-packages (from pandas)
# Requirement already satisfied: python-dateutil>=2 in /Library/Frameworks/Python.framework/Versions/3.6/lib/python3.6/site-packages (from pandas)
# Requirement already satisfied: six>=1.5 in /Library/Frameworks/Python.framework/Versions/3.6/lib/python3.6/site-packages (from python-dateutil>=2->pandas)
# Requirement already satisfied: numpy in /Library/Frameworks/Python.framework/Versions/3.6/lib/python3.6/site-packages
# Requirement already satisfied: scipy in /Library/Frameworks/Python.framework/Versions/3.6/lib/python3.6/site-packages
# Requirement already satisfied: numpy>=1.8.2 in /Library/Frameworks/Python.framework/Versions/3.6/lib/python3.6/site-packages (from scipy)
# Requirement already satisfied: sklearn in /Library/Frameworks/Python.framework/Versions/3.6/lib/python3.6/site-packages
# Requirement already satisfied: scikit-learn in /Library/Frameworks/Python.framework/Versions/3.6/lib/python3.6/site-packages (from sklearn)

# %% [markdown]
# # 設定訓練集以及測試集大小

# %%
# 測試資料大小
training_size = 700
# 訓練資料大小
testing_size = 100
# 訓練資料來源
output_file_path="/Users/Steve/PycharmProjects/Phantacy/result_all.json"

# %% [markdown]
# # 訓練程式
# 使用SVM作為訓練模型

# %%
import json
import logging
import threading

import pandas as pd
import jieba
import jieba.analyse
import numpy as np
from sklearn.feature_extraction.text import CountVectorizer
from sklearn.feature_extraction.text import TfidfTransformer
from sklearn.feature_selection import f_regression
from sklearn.feature_selection import SelectKBest
from sklearn.pipeline import Pipeline
from sklearn.svm import SVC
from sklearn.naive_bayes import MultinomialNB
from IPython.display import display, HTML

jieba.set_dictionary('dict.txt.big')

with open('stop_words.txt', encoding='utf-8') as stop_file:
    stopwords = stop_file.readlines()
stopwords = [w.strip() for w in stopwords]

svc = SVC()
nb = MultinomialNB()

def tokenize(sentence):
    return [token for token in jieba.cut(sentence) if token not in stopwords]


def read_result(file_name):
    with open(file_name, encoding='utf-8') as json_data:
        posts = json.load(json_data)
        return posts


def get_training_pipeline(classifier=nb):
#     anova_filter = SelectKBest(f_regression, k=10)
    text_clf = Pipeline([('vect', CountVectorizer(tokenizer=tokenize)),
                         ('tfidf', TfidfTransformer()),
#                          ('anova', anova_filter),
                         ('clf', classifier)])
    return text_clf


class TrainingTask(threading.Thread):
    def __init__(self, output):
        super(TrainingTask, self).__init__()
        self.is_complete = False
        self.output = output
        self.result_location = output_file_path
        self.training_size = training_size
        self.testing_size = testing_size

    def print_to_output(self, text):
        try:
            self.output.refresh_text(text)
        except:
            print(text)

    def prepare_data(self):
        posts = read_result(self.result_location)
        contents = [post['post_content'] for post in posts]
        replies = [post['fan_page_reply'] for post in posts]

        self.print_to_output("訓練集大小: {}".format(self.training_size))
        self.print_to_output("測試集大小: {}".format(self.testing_size))
        self.target_contents = contents[-self.testing_size:]
        self.target_replies = replies[-self.testing_size:]
        self.train_contents = contents[:self.training_size]
        self.train_replies = replies[:self.training_size]

    def run(self):
        self.prepare_data()
        self.print_to_output("模型訓練中 請耐心等待")

        pipeline = get_training_pipeline()
        pipeline.fit(self.train_contents, self.train_replies)
        self.predicted = pipeline.predict(self.target_contents)
        self.is_complete = True

        self.print_to_output("留言：")
        output_dict = {
            "是否該回應": self.predicted,
            "留言": [content.strip() for content in self.target_contents]
        }
    
        df = pd.DataFrame(output_dict)
        display(df)
        rate = np.mean(self.predicted == self.target_replies)
        self.print_to_output("準確率: {0:.2f}%".format(rate * 100))
# Out:
# /Library/Frameworks/Python.framework/Versions/3.6/lib/python3.6/site-packages/sklearn/utils/fixes.py:64: DeprecationWarning: inspect.getargspec() is deprecated, use inspect.signature() or inspect.getfullargspec()
#   if 'order' in inspect.getargspec(np.copy)[0]:

# %% [markdown]
# 呼叫主程式開始訓練

# %%
def main():
    TrainingTask(None).run()
    

if __name__ == '__main__':
    main()
# Out:
# Building prefix dict from /Users/Steve/PycharmProjects/Phantacy/dict.txt.big ...
# Loading model from cache /var/folders/f4/zb5h9lfx05n037z67ppm2dlh0000gn/T/jieba.u06f842be9aa390fb9509e48cb4a603a3.cache
# 訓練集大小: 700
# 測試集大小: 100
# 模型訓練中 請耐心等待
# Loading model cost 3.437 seconds.
# Prefix dict has been built succesfully.
# 留言：
#     是否該回應                                                 留言
# 0   False  首次發言，如有失禮之處望乞見諒。我是一位交通警隊員，人生至今大概也僅剩下替百姓處理交通事故的...
# 1   False  關於「颱風假」的問題想請教承辦的長官，由於外勤員警的勤務24小時不間斷，若29日為全日停止上...
# 2   False  這件衣服是給你們用來服務民眾的，不是供你們拍照打卡的。怎麼現在一堆實習生穿著衣服到處拍照呢這...
# 3   False  《根本完全敷衍~24小時不變，副署長倒下了，所長大家不想當，2線3以上不算-因爲會影響警政署...
# 4   False  針對新北市的創新作為：受理住宅竊盜案件到府服務                       ...
# 5   False  ◎員警因公受傷案，代表署長慰問案◎臺北市政府警察局大同分局重慶北路派出所警員黃威傑、警員賴世...
# 6   False  請問署長及各位長官，為何當保全公司報110指出其營業項目之公司警報器響起時，警察人員是否必須...
# 7   False  想要請最關心基層的署長，颱風夜風大雨大，路上僅剩下往來稀疏的車子，但是這種天氣卻要員警開車去...
# 8   False  ◎慰問員警因救災受傷案◎    新北市政府警察局淡水分局中山路派出所警員李瑞庭在昨(29)日...
# 9   False  #合理的懷疑警察的公正度ㄧ名自稱西螺鎮和心派出所警員的林勝智先生和自稱和心所所長的廖毓田先生...
# 10  False
# 11  False  親愛的署長大人感謝您開始重視員警過勞的問題，但現在外勤主管的過勞問題可能比基層員警還嚴重，警...
# 12  False  署長您好想請問您一個問題，我們外勤是照番號輪的，放假日期也非假日，與內勤遇紅就放完全不同。為...
# 13  False  可以請問縣市政府宣佈18-24停止上班，派出所的實報實銷如何報銷18-04  是報18-24...
# 14   True  報告署長這次學校的研習會討論，對於未來攝影係統的改進本人再推薦幾個改良的方案，等未來有經費預...
# 15  False  昨(28日)台灣退休警察人員權益促進會常務理事邱英雄學長，及其大甲昔日同仁及好友們到昔日同事...
# 16  False  當我們嚴格要求同仁遵守用槍四大安全規則的同時，是否也該幫同仁考慮到，開槍過後如何幫對方止血？...
# 17  False  署長颱風來了…年領千萬的利委在家躲颱風，被利委砍退休金的警消依然要上班！偉大愛台灣的利委跟高...
# 18  False             不是說還在跟相關單位協調中嗎！真的希望你是一個弟兄們心目中永遠的署長，加油！
# 19  False  這種賤踏執法尊嚴的案件越來越多，請問警政署有何作爲呢？ 妨害公務罪的被害人大部份都是「警察」...
# 20  False  署長您好~我要反映一些事情，反映屏東縣警察局枋寮分局的事情，希望能得到好的結果。1. 依警察...
# 21  False  長官說要增取權益是要有成績出來，警署替員警增取權益方向好像錯誤，除了不肯聽退休人員聲音外還要...
# 22  False
# 23  False  借這名專9期的學長事件想跟大家討論假設今天不以侮辱的方向去看待這件事(畢竟不是每個人都像他這...
# 24   True  懇請業務單位對於7/1新啟用的道路交通事故處理系統進行系統維修，以前使用舊系統都沒有無法開案...
# 25  False  敬愛的署長您好，我是宜蘭縣政府警察局宜蘭分局交通分隊警員，前日請鈞長針對全國交通警察機關及所...
# 26  False         可以拯救一下新的車禍處理系統嗎？比搶演唱會門票還卡，照片傳不上去，腦細胞已死了再死！
# 27  False  桃園市警察局吳明彥督察,問您一堆警察違法的問題,您卻推說是專業法律問題您無法回答,想請問您這...
# 28  False  七問陳署長不當年金改革從去年執政黨推動之後，做為基層的軍公教警消人員因人微言輕，所以除了陳抗...
# 29  False  跟軍人一樣長的服勤時間，更繁雜的工作性質，卻沒有相同的退休條件。請從辦公室出來吹毛求疵查勤的...
# ..    ...                                                ...
# 70  False  ◎員警因公受傷案，代表署長慰問案◎臺北市政府警察局南港分局舊莊派出所警員翁順天、陳柏任本（7...
# 71  False  蘋果電子報-諷刺！高市動員千警維安 陳抗30人呼完口號解散 現已無抗議民眾在現場，警方大費周...
# 72  False  可以煩請署內長官幫忙統計，基層警力花了多少時間跟人力，去做一些對社會治安跟交通無關的勤業務上...
# 73  False  《誠心》我本無心求富貴，奈何富貴逼人來。我欲執戈衛社稷，奈何雜事一直來。警察本是ㄧ家人，何必...
# 74  False  是誰在倒果為因？總統府發言人林鶴明８日表示， 「 國家元首的維安是必要公務，而脫序激烈的抗爭...
# 75  False
# 76  False  高雄市政府警察局林園分局大寮分駐所警員郭承楷，於106年7月2日3時42分騎乘普通重型機車上...
# 77  False  【員警執勤因公受傷，署駐區督察代表署長關心與慰問】    國道公路警察局第二公路警察大隊造橋...
# 78  False  請問是否能討論特勤維安的預演勤務...，現在正式特勤前，常常會安排多次的事前預演，這些預演真...
# 79  False                                  請問績效數字遊戲及專案還要玩多久？
# 80  False  ◎員警因公受傷案，代表署長慰問案◎臺北市政府警察局中山分局長春派出所警員陳國揚、蕭立威於7月...
# 81  False  【一個保安警察的心聲~暮色之年】      最近的如影隨行，遍地開花，不經意的街頭，他們（前...
# 82  False  署長來囉！正值宜蘭童玩節期間國道5號公路雪隧交通最繁忙的時刻，我們的大家長-署長今(9)日1...
# 83  False  署長您好：我是保一總隊隊員，去年年底至今，政府陸續推動相關重大法案，遭受衝擊民眾，不免走上街...
# 84  False          別再讓警察開「鋼性差、2氣囊」的車子！政府長期擺爛，警察雨天巡邏、車子一打滑就喪命
# 85  False  工欲善其事 必先利其器請長官們重視ㄧ下吧，已經有多少同仁受傷甚至送命了！！！！！請執政黨重視...
# 86  False  每逢例假日高雄市前金區轄內的謝里長深怕假日員警無處購餐便製作大批美味愛心便當提供給所內執勤員...
# 87  False  署長:這是身為長官該說的屁話嗎？我真的真的不想說髒話……但是這回應真的是去他媽的回應岡山分局...
# 88  False  值夜不算加班拒給加班費 醫院坳員工法官打臉 勞工的保障 已經超過警察了，勞工值夜 已經算 加...
# 89  False  網路已經瘋傳，署長是您生不逢時…遇到菜奇葩這個倒行逆施的猿叟……但這一年來您和葉部長沒有為警...
# 90  False  署長在這樣下去……警察真的是活不久……你為何不挺警察啊？蔡英文妳好棒喔！挺警當靠山？警察過勞...
# 91  False
# 92  False                                     我贊成 #不當得利自應返還！
# 93  False  我也贊成 #不當得利自應返還 ，那可以請不要再假、再演、再作秀了嗎？人家說「官逼民反」原來是...
# 94  False                      就已經堅持不收捐募款了，可以不要一直用我家名義非法募款嗎？
# 95  False  軍人有國防部幫他們爭取，政策因此大轉彎可續領子女教育補助。請問署長，警察沒有退輔會，那麼我們...
# 96  False                                           你是我的兄弟？！
# 97  False                                       如果線上遊戲被威脅什麼辦
# 98  False  想請教一下函中的內容？說明二(節錄)：「…於查訪公寓大廈住戶或暫住戶，在不違反任意性之前提下...
# 99  False  報告署長：警察的靠山內政部長也認為50歲以上的員警體力已不適合在外勤從事攻勢勤務，既然年改已...
#
# [100 rows x 2 columns]
# 準確率: 62.00%
